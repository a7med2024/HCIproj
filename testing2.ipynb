# %%
import socket
import pickle
soc = socket.socket()
hostname="localhost"# 127.0.0.1 #0.0.0.0
port=64252
soc.connect((hostname,port))
while True:
    data = soc.recv(1024)
    res = pickle.loads(data)
    print(res)
    if res == "exit":
        break
# Out:
# None
# Open_Palm
# None
# None
# None
# None
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# None
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# Open_Palm
# None
# None
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# None
# Thumb_Up
# None
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# None
# Closed_Fist
# Closed_Fist
# Closed_Fist
# None
# None
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# Thumb_Up
# None
# None
# Pointing_Up
# Pointing_Up
# Pointing_Up
# Pointing_Up
# ...
