# %%
pip install dollarpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
import pickle
from dollarpy import Recognizer, Template, Point

mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_drawing_styles = mp.solutions.drawing_styles

mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
templates=[] 
with open("data.model", "rb") as fp:  
    templates = pickle.load(fp)

# %%
def getPoints(label):
    cap = cv2.VideoCapture(0)#web cam =0 , else enter filename
    # Initiate holistic model
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        points = []
        left_shoulder=[]
        right_shoulder=[]
        left_elbos=[]
        right_elbos=[]
        left_wirst=[]
        right_wrist=[]
        left_pinky=[]
        right_pinky=[]
        left_index=[]
        right_index=[]
        left_hip=[]
        right_hip=[]        
        while cap.isOpened():
            ret, frame = cap.read()

            # Recolor Feed
            if ret==True:

                image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                image.flags.writeable = False        

                # Make Detections
                results = holistic.process(image)
                # print(results.face_landmarks)


                # Recolor image back to BGR for rendering
                image.flags.writeable = True   
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                # Drawing on Frame (You can remove it)
                # 2. Right hand
                mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

                # 3. Left Hand
                mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

                # 4. Pose Detections
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())
                # Export coordinates

                try:

                    # add points of wrist , elbow and shoulder
                    left_shoulder.append(Point(results.pose_landmarks.landmark[11].x,results.pose_landmarks.landmark[11].y,1))
                    right_shoulder.append(Point(results.pose_landmarks.landmark[12].x,results.pose_landmarks.landmark[12].y,2))
                    left_elbos.append(Point(results.pose_landmarks.landmark[13].x,results.pose_landmarks.landmark[13].y,3))
                    right_elbos.append(Point(results.pose_landmarks.landmark[14].x,results.pose_landmarks.landmark[14].y,4))
                    left_wirst.append(Point(results.pose_landmarks.landmark[15].x,results.pose_landmarks.landmark[15].y,5))
                    right_wrist.append(Point(results.pose_landmarks.landmark[16].x,results.pose_landmarks.landmark[16].y,6))
                    left_pinky.append(Point(results.pose_landmarks.landmark[17].x,results.pose_landmarks.landmark[17].y,7))
                    right_pinky.append(Point(results.pose_landmarks.landmark[18].x,results.pose_landmarks.landmark[18].y,8))
                    left_index.append(Point(results.pose_landmarks.landmark[19].x,results.pose_landmarks.landmark[19].y,9))
                    right_index.append(Point(results.pose_landmarks.landmark[20].x,results.pose_landmarks.landmark[20].y,10))
                    left_hip.append(Point(results.pose_landmarks.landmark[23].x,results.pose_landmarks.landmark[23].y,11))
                    right_hip.append(Point(results.pose_landmarks.landmark[24].x,results.pose_landmarks.landmark[24].y,12))

                except:
                    pass

                cv2.imshow(label, image)
            else :
                cap.release()
                cv2.destroyAllWindows()
                cv2.waitKey(100)
                break

            if cv2.waitKey(10) & 0xFF == ord('q'):
                cap.release()
                cv2.destroyAllWindows()
                cv2.waitKey(100)
                break

    cap.release()
    cv2.destroyAllWindows()
    points = left_shoulder+right_shoulder+left_elbos+right_elbos+left_wirst+right_wrist+left_pinky+right_pinky+left_index+right_index+left_hip+right_hip
    print(label)
    return points

# %%
vid = "Dataset/hook/hook correct.mp4"
points = getPoints("Correct Hook Execution") 
points
# Out:
# Correct Hook Execution
# [(0.7097398638725281, 0.8182456493377686), stroke 1,
#  (0.7094537019729614, 0.8184009790420532), stroke 1,
#  (0.7091649174690247, 0.8184903860092163), stroke 1,
#  (0.7085583209991455, 0.8184791803359985), stroke 1,
#  (0.7068063020706177, 0.8184436559677124), stroke 1,
#  (0.7051386833190918, 0.8180102705955505), stroke 1,
#  (0.7040557861328125, 0.8175305724143982), stroke 1,
#  (0.703840970993042, 0.8174394965171814), stroke 1,
#  (0.7038203477859497, 0.8176364898681641), stroke 1,
#  (0.7037120461463928, 0.8173142671585083), stroke 1,
#  (0.7034791111946106, 0.8159697651863098), stroke 1,
#  (0.7034324407577515, 0.8148477077484131), stroke 1,
#  (0.703462541103363, 0.8144069314002991), stroke 1,
#  (0.7033011317253113, 0.812264084815979), stroke 1,
#  (0.7031978964805603, 0.8092365860939026), stroke 1,
#  (0.7013351917266846, 0.8054805397987366), stroke 1,
#  (0.7002365589141846, 0.8026577830314636), stroke 1,
# ...

# %%
import pickle
with open("data.model", "wb") as fp:
    pickle.dump(templates, fp)

# %%
#hook wrong correct
vid = "Dataset/hook/hook correct.mp4"
points = getPoints("hook correct") 
tmpl_2 = Template('hook correct', points)
templates.append(tmpl_2)

#hook no defense no torso twist
# vid = "Dataset/hook/hook wrong no torso twist no defence .mp4"
# points = getPoints(vid,"hook wrong no torso twist no defence") 
# tmpl_2 = Template('hook wrong no torso twist no defence', points)
# templates.append(tmpl_2)

#hook wrong no torso twist 
vid = "Dataset/hook/hook wrong no torso twist.mp4"
points = getPoints("hook wrong no torso twist") 
tmpl_2 = Template('hook wrong no torso twist', points)
templates.append(tmpl_2)

#hook wrong no defense
vid = "Dataset/hook/hook wrong no defence .mp4"
points = getPoints("hook wrong no defence") 
tmpl_2 = Template('hook wrong no defence', points)
templates.append(tmpl_2)




#UPPER
#uppercut correct
vid = "Dataset/uppercut/uppercut correct.mp4"
points = getPoints("uppercut correct") 
tmpl_2 = Template('uppercut correct', points)
templates.append(tmpl_2)

#uppercut wrong (no torso & ankle  twist)
vid = "Dataset/uppercut/uppercut wrong (no torso & ankle  twist).mp4"
points = getPoints("uppercut wrong (no torso & ankle  twist)") 
tmpl_2 = Template('uppercut wrong (no torso & ankle  twist)', points)
templates.append(tmpl_2)

#uppercut wrong no defence
vid = "Dataset/uppercut/uppercut wrong no defence.mp4"
points = getPoints("uppercut wrong no defence") 
tmpl_2 = Template('uppercut wrong no defence', points)
templates.append(tmpl_2)




#right stroke wrong no defence
vid = "Dataset/right/(right) correct.mp4"
points = getPoints("(right) correct") 
tmpl_2 = Template('(right) correct', points)
templates.append(tmpl_2)

#right stroke wrong hand down no torso twist
vid = "Dataset/right/(right) hand down no torso twist.mp4"
points = getPoints("(right) hand down no torso twist") 
tmpl_2 = Template('(right) hand down no torso twist', points)
templates.append(tmpl_2)
#right wrong  wrong return
vid = "Dataset/right/(right) wrong return.mp4"
points = getPoints("(right) wrong return") 
tmpl_2 = Template('(right) wrong return', points)
templates.append(tmpl_2)
# Out:
# hook correct
# hook wrong no torso twist
# hook wrong no defence
# uppercut correct
# uppercut wrong (no torso & ankle  twist)
# uppercut wrong no defence
# (right) correct
# (right) hand down no torso twist
# (right) wrong return

# %%
#TEST
vid = "Dataset/uppercut/uppercut wrong no defence II.mp4"
points = getPoints("uppercut wrong no defence II") 



import time 
start = time.time()
recognizer = Recognizer(templates)
result = recognizer.recognize(points)
end = time.time()
print(result[0])
print("time taken to classify:"+ str(end-start))
# Out:
# uppercut wrong no defence II
# hook correct
# time taken to classify:0.0389714241027832

# %%
print(result)
# Out:
# ('uppercut correct', 0.3490008729059654)

# %%
1- Determine Points (Create empty list/s)
2- Reshape Meidapipe format into Point Format (append to list)
3- Record Dataset (3 Circle,3 Rectangle ,3 Square) via thumb
3- Record Dataset (3 Circle,3 Rectangle ,3 Square) via index
4- Training (2 samples for each class) via thumb
4- Training (2 samples for each class) via index
5- Testing (1 sample for each class)
